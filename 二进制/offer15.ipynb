# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        res = 0
        while n:
            res += 1
            n &= n - 1
        return res

# %% [markdown]
# ![image.png](attachment:4ac92bbb-ff03-4522-96ce-bdfaccc2d4b4.png)
